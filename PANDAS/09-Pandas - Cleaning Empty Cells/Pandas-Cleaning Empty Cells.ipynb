# %% [markdown]
# Return a new Data Frame with no empty cells:

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

new_df = df.dropna()

print(new_df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch             Ticket      Fare            Cabin Embarked
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0           PC 17599   71.2833              C85        C
# 3              4         1       1                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1      0             113803   53.1000             C123        S
# 6              7         0       1                                                             McCarthy, Mr. Timothy J    male  54.00      0      0              17463   51.8625              E46        S
# ...

# %% [markdown]
# Remove all rows with NULL values:

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

df.dropna(inplace = True)

print(df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch             Ticket      Fare            Cabin Embarked
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0           PC 17599   71.2833              C85        C
# 3              4         1       1                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1      0             113803   53.1000             C123        S
# 6              7         0       1                                                             McCarthy, Mr. Timothy J    male  54.00      0      0              17463   51.8625              E46        S
# ...

# %% [markdown]
# Replace NULL values with the number 130:

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

df.fillna(130, inplace = True)

# %% [markdown]
# Replace NULL values in the "Calories" columns with the number 130:

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

df["PassengerId"].fillna(130, inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_10048\3033541782.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["PassengerId"].fillna(130, inplace = True)

# %% [markdown]
# Calculate the MEAN, and replace any empty values with it:

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

x = df["PassengerId"].mean()

df["PassengerId"].fillna(x, inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_10048\4157193962.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["PassengerId"].fillna(x, inplace = True)

# %% [markdown]
# Calculate the MEDIAN, and replace any empty values with it:

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

x = df["PassengerId"].median()

df["PassengerId"].fillna(x, inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_10048\1872643734.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["PassengerId"].fillna(x, inplace = True)

# %% [markdown]
# Calculate the MODE, and replace any empty values with it:

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

x = df["PassengerId"].mode()[0]

df["PassengerId"].fillna(x, inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_10048\723485797.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["PassengerId"].fillna(x, inplace = True)
